# %% [markdown]
# # Fashion Mnist 10 Loss Fun
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/dgaida/wpf_dlml_th_public/blob/main/assets/exercises/week_05/03_fashion_mnist_10_loss_fun.ipynb)
#
# This notebook contains an exercise from the Deep Learning, Machine Learning, and AI course.

# %% [markdown]
# ## Instructions for Google Colab
#
# Since this notebook depends on `utils_fmnist.py`, you need to upload it to your Colab environment:
# 1. Click on the **folder icon** in the left sidebar.
# 2. Click on the **upload icon** (file with an arrow) or drag and drop `utils_fmnist.py` into the file area.
# 3. Ensure `utils_fmnist.py` is in the same directory as this notebook (usually `/content/`).

# %%
import pickle
from tensorflow.keras.models import load_model

# %%
from utils_fmnist import *


# Daten laden
(x_train, y_train), (x_test, y_test) = load_data_full()

# Modell erstellen
model = Sequential()
model.add(Flatten(input_shape=[28, 28]))
model.add(Dense(units=300, activation='relu'))
model.add(Dense(units=10, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer=SGD(), metrics=['accuracy'])

print(model.summary())

# Modell trainieren
history = model.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test),
                    batch_size=32, verbose=1)

# Vorhersagen auf den Testdaten
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)  # Klassenindex für jede Vorhersage

print(y_test[0, :])
print(y_pred_classes[0, :])
